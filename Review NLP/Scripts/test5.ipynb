# %%
import pandas as pd
from transformers import pipeline
data = pd.read_csv('Flipkart_Amazon Mobile Reviews - Flipkart_Amazon Mobile Reviews.csv')
df = data.fillna("EMPTY")
#df1 = df.iloc[0:3571] #OnePlus Nord CE 2 5G (Gray Mirror, 8GB RAM, 128GB Storage)
#df2 = df.iloc[3572:7901] #OPPO A31 (Mystery Black, 6GB RAM, 128GB Storage)
#df3 = df.iloc[7902:10067] #realme narzo 50A (Oxygen Blue , 4GB RAM + 64 GB Storage)
#df4 = df.iloc[10067:13835] #Redmi 10 Prime (Bifrost Blue 4GB RAM 64GB ROM
#df5 = df.iloc[13836:18295] #Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Storage)
#df6 = df.iloc[18296:21019] #Redmi Note 11 (Space Black, 4GB RAM, 64GB Storage)
#df7 = df.iloc[21020:22359] #Samsung Galaxy M32
#df8 = df.iloc[22360:23778] #vivo iQOO Z6 5G (Chromatic Blue, 6GB RAM, 128GB Storage)

# %%
from transformers import pipeline
labels=[]

pipe = pipeline(model="facebook/bart-large-mnli")
for i in range(21018,22357):
  results = pipe(df["Review_Body"].iloc[i],candidate_labels=["camera", "battery", "display", "performance", "value for money"],)
  resultsdf=pd.DataFrame.from_dict(results)
  var = resultsdf["labels"].iloc[0]
  labels.append(var)
  print(i)
  #print(labels)
  #print(index)
my_list = list(zip(labels))
df_my_list_oneplus = pd.DataFrame(my_list,columns=['Label'])
df_my_list_oneplus.to_csv("samsungm32.csv")
# Out:
# 21018
# 21019
# 21020
# 21021
# 21022
# 21023
# 21024
# 21025
# 21026
# 21027
# 21028
# 21029
# 21030
# 21031
# 21032
# 21033
# 21034
# 21035
# 21036
# 21037
# 21038
# 21039
# 21040
# 21041
# 21042
# 21043
# 21044
# 21045
# 21046
# 21047
# 21048
# 21049
# 21050
# 21051
# 21052
# 21053
# 21054
# 21055
# 21056
# 21057
# 21058
# 21059
# 21060
# 21061
# 21062
# 21063
# 21064
# 21065
# 21066
# 21067
# 21068
# 21069
# 21070
# 21071
# 21072
# 21073
# 21074
# 21075
# 21076
# 21077
# 21078
# 21079
# 21080
# 21081
# 21082
# 21083
# 21084
# 21085
# 21086
# 21087
# 21088
# 21089
# 21090
# 21091
# 21092
# 21093
# 21094
# 21095
# 21096
# 21097
# 21098
# 21099
# 21100
# 21101
# 21102
# 21103
# 21104
# 21105
# 21106
# 21107
# 21108
# 21109
# 21110
# 21111
# 21112
# 21113
# 21114
# 21115
# 21116
# 21117
# 21118
# 21119
# 21120
# 21121
# 21122
# 21123
# 21124
# 21125
# 21126
# 21127
# 21128
# 21129
# 21130
# 21131
# 21132
# 21133
# 21134
# 21135
# 21136
# 21137
# 21138
# 21139
# 21140
# 21141
# 21142
# ...
